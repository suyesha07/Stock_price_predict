# %% [markdown]
# <a href="https://colab.research.google.com/github/suyesha07/Stock_price_predict/blob/main/Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STOCK PRICE PREDICTION using ML algorithms
#
# ## By Suyesha Bhattacharjee

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
training_data = pd.read_csv('Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# feature scaling

from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
# reshaping

x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 2s 2ms/step - loss: 1.3724
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.1485
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9616
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.8066
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6782
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5711
# Epoch 7/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4817
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4070
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3451
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2936
# Epoch 11/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2507
# Epoch 12/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2153
# Epoch 13/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1860
# Epoch 14/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1620
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1421
# Epoch 16/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1261
# Epoch 17/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1133
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1030
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0949
# Epoch 20/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0885
# Epoch 21/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0835
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0795
# Epoch 23/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 24/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0741
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0724
# Epoch 26/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0709
# Epoch 27/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0698
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 29/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0681
# Epoch 30/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0675
# Epoch 31/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0669
# Epoch 32/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0663
# Epoch 33/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0657
# Epoch 34/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0652
# Epoch 35/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0647
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0642
# Epoch 37/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0636
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 39/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0625
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0619
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0613
# Epoch 42/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0606
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0593
# Epoch 45/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0586
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0579
# Epoch 47/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0571
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0556
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0548
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0540
# Epoch 52/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0531
# Epoch 53/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0522
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0513
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0504
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0495
# Epoch 57/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0485
# Epoch 58/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0475
# Epoch 59/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0464
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0454
# Epoch 61/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0443
# Epoch 62/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0432
# Epoch 63/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0420
# Epoch 64/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0409
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 66/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0385
# Epoch 67/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0373
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0361
# Epoch 69/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0348
# Epoch 70/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 71/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 72/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0310
# Epoch 73/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0298
# Epoch 74/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0285
# Epoch 75/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0272
# Epoch 76/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0259
# Epoch 77/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0246
# Epoch 78/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 79/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0220
# Epoch 80/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0208
# Epoch 81/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 82/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0184
# Epoch 83/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 84/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 85/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 86/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 87/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 88/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 89/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 90/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 91/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 92/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 93/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.
200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8971e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.8536e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.8120e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.7748e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.7355e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.6965e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 5ms/step - loss: 3.6610e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.6205e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 5ms/step - loss: 3.5889e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.5505e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.5267e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4904e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4547e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4244e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3953e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3778e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3479e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3486e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3014e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2702e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2573e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2222e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2109e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1744e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1592e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1436e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1158e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1157e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0788e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0691e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0531e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0417e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0324e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0033e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9994e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9914e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9707e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9747e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9728e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9540e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9228e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9205e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9139e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9036e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8958e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8883e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8780e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8769e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8633e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8645e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8818e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8509e-04

# %%
# getting the real stock of 2017 i.e., importing the test dataset

test_data = pd.read_csv('Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[772.4789 ],
#        [779.9286 ],
#        [778.16516],
#        [785.2082 ],
#        [793.5489 ],
#        [794.6252 ],
#        [792.5131 ],
#        [794.0949 ],
#        [794.34546],
#        [794.05066],
#        [793.1128 ],
#        [792.60205],
#        [793.9253 ],
#        [794.17596],
#        [805.0608 ],
#        [810.20544],
#        [815.8459 ],
#        [813.7253 ],
#        [799.58685],
#        [786.42004]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# getting the predicted stock price of 2012-2016

predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
# visualizing the whole training data results

plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
